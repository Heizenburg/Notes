# %% [markdown]
# ## PnP B2B

# %% [markdown]
# This notebook removes older files and behind recent (6 days) files in each.

# %%
import os
import time

# %%
def delete_old_files(folder_path, age_threshold_days):
    current_time = time.time()

    # Calculate the age threshold in seconds
    age_threshold = age_threshold_days * 24 * 60 * 60

    # Iterate over all the subfolders and files in the given folder
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            modified_time = os.path.getmtime(file_path)

            # Calculate the age of the file in seconds
            age = current_time - modified_time

            # Check if the file is older than the specified threshold
            if age > age_threshold:
                # Delete the file
                os.remove(file_path)
                modified_date = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(modified_time))
                print(f"Deleted file: {file_path} (Modified Date: {modified_date})")

# %%
folder_path = r"R:\RawData\PNP SAP\Client File Downloads"
age_threshold_days = 60

delete_old_files(folder_path, age_threshold_days)
# Out:
# Deleted file: R:\RawData\PNP SAP\Client File Downloads\AB Inbev (SAB)\_South_African_Breweries_FiscalMonthExtract_2024004.csv.gz (Modified Date: 2023-07-04 09:29:06)
# Deleted file: R:\RawData\PNP SAP\Client File Downloads\AB Inbev (SAB)\_South_African_Breweries_FiscalMonthExtract_2024005.csv.gz (Modified Date: 2023-08-04 14:22:14)
# Deleted file: R:\RawData\PNP SAP\Client File Downloads\Acdoco\Acdoco_SA_2007_(Pty)_Ltd_FiscalMonthExtract_2024004.csv.gz (Modified Date: 2023-07-04 14:21:06)
# Deleted file: R:\RawData\PNP SAP\Client File Downloads\Acdoco\Acdoco_SA_2007_(Pty)_Ltd_FiscalMonthExtract_2024005.csv.gz (Modified Date: 2023-08-06 21:22:39)
# Deleted file: R:\RawData\PNP SAP\Client File Downloads\Adcock Ingram\Adcock_Ingram_Healthcare_FiscalMonthExtract_2023000.csv.gz (Modified Date: 2023-03-06 11:18:05)
# Deleted file: R:\RawData\PNP SAP\Client File Downloads\Adcock Ingram\Adcock_Ingram_Healthcare_FiscalMonthExtract_2023010.csv.gz (Modified Date: 2023-01-05 10:27:14)
# ...
